# %%
# https://docs.ultralytics.com/tasks/segment/

# %%
import os
os.chdir(r'/kaggle/working')
from IPython.display import FileLink

# %%
# !pip install ultralytics &> /dev/null

# %%
from ultralytics import YOLO
from IPython.display import Image

# %%
# %%time
model = YOLO('yolov8n-seg.pt')
# Out:
# ...
# 100%|██████████| 6.73M/6.73M [00:00<00:00, 25.9MB/s]
# CPU times: user 153 ms, sys: 48.6 ms, total: 202 ms
# Wall time: 1.73 s

# %%
# !wget https://raw.githubusercontent.com/facebookresearch/segment-anything/main/notebooks/images/dog.jpg &> /dev/null

# %%
Image(filename='dog.jpg')

# %%
result = model.predict('dog.jpg', save=True, imgsz=1024, conf=0.5)
# Out:
# image 1/1 /kaggle/working/dog.jpg: 704x1024 1 person, 1 dog, 1 bowl, 515.4ms
# Speed: 24.3ms preprocess, 515.4ms inference, 42.4ms postprocess per image at shape (1, 3, 704, 1024)
# Results saved to runs/segment/predict

# %%
Image(filename='runs/segment/predict/dog.jpg')
