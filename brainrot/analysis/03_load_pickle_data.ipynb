# %%
import pickle

import numpy as np
from PIL import Image

# %%
with open("video_data_2.pkl", "rb") as f:
    video_data = pickle.load(f)

# %%
len(video_data)
# Out:
# 1472

# %%
for item in video_data:
    print(item.keys())
    video_path = item["video_path"]
    embedding = item["embedding"]
    thumbnail_path = item["thumbnail_path"]
    thumbnail = Image.open(item["thumbnail_path"])
    break
# Out:
# dict_keys(['video_id', 'video_path', 'embedding', 'thumbnail_path'])

# %%
video_path
# Out:
# '/home/aatman/Aatman/Tattle/tattle-research/brainrot/main_analysis_2/visualisation/video_reels/DI3VngZvkSu.mp4'

# %%
thumbnail_path
# Out:
# 'thumbnails/DI3VngZvkSu.jpg'

# %%
len(embedding)
# Out:
# 512

# %%
# For operations that only need embeddings, you can load just the embeddings
embeddings_array = np.load("video_embeddings.npy")

# %%
print(type(embeddings_array[0]))
print(len(embeddings_array[0]))
# Out:
# <class 'numpy.ndarray'>
# 512

# %%
thumbnail
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=720x1280>
